# %%
# In the below elements which of them are values or an expression?

values can be integer or string 'hello' , -87.8 , 6

expressions will be mathematical operators * , - , + , /


# What is the difference between string and variable?

A Variable is a store of information, and a String is a type of information you would store in a Variable. 
A String is usually words, enclosed with ""
Eg.
String x ="study with ineuron"
X is the Variable

# Describe three different data types?

Strings "ineuron", "23.34" Text - anything between" "
Integers 1234 Integers in form of Whole numbers
Floats 1.23 Floats in form of Decimal Numbers

# What is an expression made up of? What do all expressions do?

An expression is a combination of values, variables, operators.

# This assignment statements, like spam = 10. What is the difference between an expression and a statement?
expression is 10 so, statement A statement does something in this is spam.

#After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

output comes 23

# What should the values of the following two terms be?

'spam'+'spamspam'
'spam'*3

output 'spamspamspam'

# Why is eggs a valid variable name while 100 is invalid?

variable are used in 0 to 99 so 100 is invalid

# What three functions can be used to get the integer, floating-point number, or string version of a value?

int() , float() , str()


# Why does this expression cause an error? How can you fix it?
'I have eaten'+99+'burritos.'

only contain str in '' not 99

correct out is 'I have eaten99burritos'
